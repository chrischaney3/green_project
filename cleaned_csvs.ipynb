# %%
# import dependencies
import pandas as pd

# %%
# get 2014 data into csv
df_2014 = pd.read_csv('04232015altfuelstations (1).csv')
df_2014.head()
# Out:
#   Fuel Type Code                         Station Name    Street Address  \
# 0            LPG                        Irish Propane   70 Katherine St
# 1           ELEC                            Latitudes  2401 Highway 528
# 2           ELEC         American Bush - Solar Canopy      2630 S 300 W
# 3           ELEC  McDonald's #31850 - Flower Mound TX       3601 FM 407
# 4           ELEC                      CITY OF SEATTLE       600 Pine St
#
#           Intersection Directions            City State    ZIP  Plus4  \
# 0           At Bailey and Clinton         Buffalo    NY  14210    NaN
# 1                             NaN      Rio Rancho    NM  87124    NaN
# 2  Located across from Tire World  Salt Lake City    UT  84115    NaN
# 3                             NaN    Flower Mound    TX  75028    NaN
# 4                             NaN         Seattle    WA  98101    NaN
#
#   Station Phone Status Code  ...               Updated At Owner Type Code  \
# ...

# %%
# Check column names
for col in df_2014.columns:
    print(col)
# Out:
# Fuel Type Code
# Station Name
# Street Address
# Intersection Directions
# City
# State
# ZIP
# Plus4
# Station Phone
# Status Code
# Expected Date
# Groups With Access Code
# Access Days Time
# Cards Accepted
# BD Blends
# NG Fill Type Code
# NG PSI
# EV Level1 EVSE Num
# EV Level2 EVSE Num
# EV DC Fast Count
# EV Other Info
# EV Network
# EV Network Web
# Geocode Status
# Latitude
# Longitude
# Date Last Confirmed
# ID
# Updated At
# Owner Type Code
# Federal Agency ID
# Federal Agency Name
# Open Date
# Hydrogen Status Link
# NG Vehicle Class
# LPG Primary
# E85 Blender Pump
# EV Connector Types

# %%
# Create a new dataframe with only these columns ["Fuel Type Code", "Station Name", "City", "State", "Status Code", "Latitude", "Longitude", "Groups With Access Code"]
cleaned_2014 = df_2014[["Fuel Type Code", "Station Name", "City", "State", "Status Code", "Latitude", "Longitude", "Groups With Access Code"]]
cleaned_2014.head()
# Out:
#   Fuel Type Code                         Station Name            City State  \
# 0            LPG                        Irish Propane         Buffalo    NY
# 1           ELEC                            Latitudes      Rio Rancho    NM
# 2           ELEC         American Bush - Solar Canopy  Salt Lake City    UT
# 3           ELEC  McDonald's #31850 - Flower Mound TX    Flower Mound    TX
# 4           ELEC                      CITY OF SEATTLE         Seattle    WA
#
#   Status Code   Latitude   Longitude Groups With Access Code
# 0           E  42.859400  -78.858933                  Public
# 1           E  35.218430 -106.663000                  Public
# 2           E  40.714420 -111.900105                  Public
# 3           E  33.071809  -97.085119                  Public
# 4           E  47.612514 -122.335409                  Public

# %%
# get 2012 data into csv
df_2012 = pd.read_csv('altfuelstationsapr42012.csv')
df_2012.head()
# Out:
#   Fuel Type Code                           Station Name       Street Address  \
# 0            CNG  Alagasco Tuscaloosa Operations Center   5220 Metro Park Dr
# 1            CNG  Alagasco Montgomery Operations Center     2951 Chestnut St
# 2            CNG                            Fort Gordon            105th Ave
# 3            CNG        Clayton County Fleet Maintenace  1348 Government Cir
# 4            CNG         Clean Energy - PS Energy - UFO  340 Whitehall St SW
#
#                              Intersection Directions         City State  \
# 0                                                NaN   Tuscaloosa    AL
# 1                                                NaN   Montgomery    AL
# 2                                     Building 61300  Fort Gordon    GA
# 3           I-75 south of Atlanta to State Route 138    Jonesboro    GA
# 4  From I-7585 N, exit 91 to Central Avenue, left...      Atlanta    GA
#
#      ZIP   Plus4 Station Phone Status Code  ... EV Level2 EVSE Num  \
# ...

# %%
# Create a new dataframe with only these columns ["Fuel Type Code", "Station Name", "City", "State", "Status Code", "Latitude", "Longitude", "Groups With Access Code"]
cleaned_2012 = df_2012[["Fuel Type Code", "Station Name", "City", "State", "Status Code", "Latitude", "Longitude", "Groups With Access Code"]]
cleaned_2012.head()
# Out:
#   Fuel Type Code                           Station Name         City State  \
# 0            CNG  Alagasco Tuscaloosa Operations Center   Tuscaloosa    AL
# 1            CNG  Alagasco Montgomery Operations Center   Montgomery    AL
# 2            CNG                            Fort Gordon  Fort Gordon    GA
# 3            CNG        Clayton County Fleet Maintenace    Jonesboro    GA
# 4            CNG         Clean Energy - PS Energy - UFO      Atlanta    GA
#
#   Status Code   Latitude  Longitude         Groups With Access Code
# 0           E  33.161768 -87.556760             Private access only
# 1           E  32.367163 -86.267396             Private access only
# 2           E  33.413446 -82.176044       Private - government only
# 3           E  33.535725 -84.346895       Private - government only
# 4           E  33.745474 -84.400021  Private - fleet customers only

# %%
# get 2021 data into csv
df_2021 = pd.read_csv('alt_fuel_stations (Jul 29 2021).csv')
df_2021.head()
# Out:
# /Users/katherinewinder/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3186: DtypeWarning: Columns (3,6,10,13,14,15,16,20,29,31,33,34,35,36,43,45,46,47,49,52,53,54,56,57,58,59,60,61,62,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Fuel Type Code                                       Station Name  \
# 0            CNG               Spire - Montgomery Operations Center
# 1            CNG                                PS Energy - Atlanta
# 2            CNG       Metropolitan Atlanta Rapid Transit Authority
# 3            CNG                              United Parcel Service
# 4            CNG  Clean Energy - Texas Department of Transportation
#
#          Street Address                            Intersection Directions  \
# 0      2951 Chestnut St                                                NaN
# ...

# %%
# Create a new dataframe with only these columns ["Fuel Type Code", "Station Name", "City", "State", "Status Code", "Latitude", "Longitude", "Groups With Access Code"]
cleaned_2021 = df_2021[["Fuel Type Code", "Station Name", "City", "State", "Status Code", "Latitude", "Longitude", "Groups With Access Code"]]
cleaned_2021.head()
# Out:
#   Fuel Type Code                                       Station Name  \
# 0            CNG               Spire - Montgomery Operations Center
# 1            CNG                                PS Energy - Atlanta
# 2            CNG       Metropolitan Atlanta Rapid Transit Authority
# 3            CNG                              United Parcel Service
# 4            CNG  Clean Energy - Texas Department of Transportation
#
#          City State Status Code   Latitude  Longitude  \
# 0  Montgomery    AL           E  32.367916 -86.267021
# 1     Atlanta    GA           E  33.745843 -84.398837
# 2     Atlanta    GA           E  33.821911 -84.367461
# 3     Atlanta    GA           E  33.760256 -84.543822
# 4     Houston    TX           E  29.779918 -95.435385
#
#              Groups With Access Code
# 0                            Private
# 1     Public - Card key at all times
# 2          Private - Government only
# 3                            Private
# 4  Public - Credit card at all times

# %%
# Export each cleaned csv
cleaned_2012.to_csv("Resources/2012_ev_data.csv", index=False)

# %%
cleaned_2014.to_csv("Resources/2014_ev_data.csv", index=False)

# %%
cleaned_2021.to_csv("Resources/2021_ev_data.csv", index=False)
